# %%
import recon

# %%
rec = recon.PhaseSpaceReconstructor()

# %%
rec.load_image("Charge13+_Volt166_Mass48_Brightness0_Gain0_Shutter2722_Trigger_Off_T_Delay_us40_PulseLength_us400_01-02-2017_15h30m57_OriginalPicture.png")

# %%
print(rec.results)
# Out:
# {'emittance_x': 9.124463101753412e-05, 'emittance_x_corrected': 9.071902917471849e-05, 'alpha_x': 95.80374427906091, 'beta_x': 25.176538877870236, 'gamma_x': 364.5996561487727, 'emittance_y': 5.8548350273806646e-05, 'emittance_y_corrected': 5.8117497048891594e-05, 'alpha_y': 78.25612183240034, 'beta_y': 20.90833369019436, 'gamma_y': 292.9463770286013}

# %%
rec.filter_offset_value = 180.
rec.filter_clip_value_min = 1
rec.filter_clip = True
rec.filter_median = True
rec.filter_offset = True
rec.peakfind_distance_x = 30
rec.peakfind_distance_y = 30
rec.peakfind_height_x = 70
rec.peakfind_height_y = 60
rec.image_scale_x = 0.000041
rec.image_scale_y = 0.000041
rec.print_results()
rec.plot_input()
rec.plot_filtered_roi()
rec.plot_marginals()
rec.plot_reconst()
# Out:
# emittance_x = 7.476626581704163e-06
# emittance_x_corrected = 7.46588766061706e-06
# alpha_x = -0.7947758712811928
# beta_x = 1.799741963755162
# gamma_x = 0.9066125691520257
# emittance_y = 7.915531370993513e-06
# emittance_y_corrected = 7.90261557038251e-06
# alpha_y = -0.6560632560720169
# beta_y = 2.0648089581937543
# gamma_y = 0.6927609405661985
# H:\PhD\GitHubRepos\PepperpotSim\recon.py:216: RuntimeWarning: invalid value encountered in sqrt
#   root = np.sqrt((alpha * x/beta)**2 + emit - gamma*x**2)

# %%
# import matplotlib.pyplot as plt
# plt.figure()
# plt.plot(rec.map_x)
# plt.plot(rec.map_xp)
# plt.plot(rec.image_masked_marginal_x/100000)
# plt.figure()
# plt.plot(rec.map_y)
# plt.plot(rec.map_yp)
# plt.plot(rec.image_masked_marginal_y/100000)
# plt.show()
# plt.figure()
# plt.plot(rec.holes_x,"x")

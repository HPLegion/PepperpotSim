# %%
import numpy as np
import scipy.ndimage
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import pepper
import imageio

# %%
img = imageio.imread("Charge13+_Volt166_Mass48_Brightness0_Gain0_Shutter2722_Trigger_Off_T_Delay_us40_PulseLength_us400_01-02-2017_15h30m57_OriginalPicture.png")

# %%
img
# Out:
# Image([[ 96, 320,  64, ..., 224, 128, 128],
#        [ 96, 160,  32, ..., 320, 160, 192],
#        [ 64, 160, 128, ..., 192, 288, 320],
#        ...,
#        [ 64, 192, 160, ...,  32,  64, 192],
#        [  0,  64, 192, ...,  32, 224, 160],
#        [  0, 192,  32, ..., 192,  96, 160]], dtype=uint16)

# %%
def show_img(img):
    plt.figure(figsize=(15,10))
    plt.imshow(img)
    plt.colorbar()
    plt.show()

# %%
show_img(img)

# %%
def determine_background(img):
    return img[:100, :100].mean()

# %%
determine_background(img)
# Out:
# 180.25630000000001

# %%
img2 = img - determine_background(img)
show_img(img2)

# %%
img3 = scipy.ndimage.median_filter(img2, size=2)
show_img(img3)

# %%
img4 = np.clip(img3, 1 , None)
show_img(np.log(img4))

# %%
plt.figure()
plt.plot(img4.sum(0))

plt.figure()
plt.plot(img4.sum(1))

plt.show()
